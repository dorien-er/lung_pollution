# %%
import pandas as pd

pollution_data = pd.read_csv("../lung_pollution/data/clean_merged_dataset_covid_pollution.csv",
                             sep=',',
                             decimal='.',
                            )
pollution_data.head()
# Out:
#    Unnamed: 0                  county  year  NO2_annualMean  NO2_hrOver200  \
# 0           0  SK Freiburg i.Breisgau  2019       15.757110       0.000000
# 1           1  SK Freiburg i.Breisgau  2013       15.478438       0.005519
# 2           2  SK Freiburg i.Breisgau  2015       20.099360       0.000000
# 3           3  SK Freiburg i.Breisgau  2012       19.453450       0.000000
# 4           4  SK Freiburg i.Breisgau  2010       22.194410       0.000000
#
#    NO_annualMean  O3_annualMean  O3_daysOver120  O3_dailyMaxAnnualMean  \
# 0       6.600048       55.45190        6.000000               83.70603
# 1       9.045152       48.39038        1.000000               76.72329
# 2      18.775820       55.36761        8.000000               85.60000
# 3       7.224937       50.41513        0.728386               74.44929
# 4       7.994131       47.72202        0.587459               74.22727
#
#    O3_dailyHourlyMax  ...  PM10_daysOver50  PM2_5_annualMean  \
# ...

# %%
pollution_data.shape
# Out:
# (3990, 22)
